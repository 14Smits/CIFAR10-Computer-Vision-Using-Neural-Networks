# %%
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder, CIFAR10
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
import random
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
# Define transforms for the images (you can add more augmentation as needed)
transform = transforms.Compose([
    transforms.ToTensor(),
])

# Load the CIFAR-10 dataset using torchvision
cifar10_train = CIFAR10(root='.', train=True, download=True, transform=transform)
cifar10_test = CIFAR10(root='.', train=False, download=True, transform=transform)

# Split dataset into training and validation sets
train_size = int(0.8 * len(cifar10_train))
val_size = len(cifar10_train) - train_size
train_dataset, val_dataset = random_split(cifar10_train, [train_size, val_size])

# Create data loaders
batch_size = 100
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(cifar10_test, batch_size=batch_size, shuffle=False)  # No need to shuffle test set

# Function to show random images
def show_random_images(dataset, class_names, ncols=3):
    fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(10, 10))
    random_indices = random.sample(range(len(dataset)), 9)
    
    for i, idx in enumerate(random_indices):
        image, label = dataset[idx]
        image = image.permute(1, 2, 0)  # (C, H, W) to (H, W, C)
        ax = axes.flat[i]
        ax.imshow(image)
        ax.axis('off')
        ax.set_title(f'CIFAR-10 Class: {class_names[label]}')
    
    plt.tight_layout()
    plt.show()

# Display random images with labels
show_random_images(train_dataset, cifar10_train.classes)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
class CNN(nn.Module):
    def __init__(self, num_classes):
        super(CNN, self).__init__()
        # Convolutional layers
        self.conv1 = nn.Conv2d(in_channels=3, out_channels=16, kernel_size=3, stride=1, padding=1) #we have 3 in channels since we have 3 color rgb. 
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        # Max pooling layer
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        # Fully connected layers
        self.fc1 = nn.Linear(32 * 8 * 8, 256)  # Adjust input size based on your image dimensions
        self.fc2 = nn.Linear(256, num_classes)
    
    def forward(self,x):    
        x=self.pool(F.relu(self.conv1(x)))
        x=self.pool(F.relu(self.conv2(x)))
        x=torch.flatten(x,1) #We flatten our data along the color channels. So, first we had [batch_size, channels, height, width] and now we will have [batch_size, channels * height * width].
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2(x))
        return x

# %%
num_classes = len(cifar10_train.classes) # Number of classes is based on the dataset
model = CNN(num_classes)
loss_fn=nn.CrossEntropyLoss()
optimizer=optim.Adam(model.parameters(),lr=0.001) #We will use the Adam optimizer in this case. 
print(model)
# Out:
# CNN(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=2048, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
def train_model(model, optimizer, loss_fn, train_loader, test_loader, epochs=10):
    for epoch in range(epochs):
        running_loss = 0.0
        
        # Training phase
        model.train()  # Set the model to training mode
        for i, data in enumerate(train_loader, 0):
            inputs, labels = data
            
            # Zero the gradients
            optimizer.zero_grad()
            
            # Forward pass + backward pass + optimize
            outputs = model(inputs)
            loss = loss_fn(outputs, labels)
            loss.backward()
            optimizer.step()
            
            # Print statistics
            running_loss += loss.item()
            if i % 10 == 9:    # Print every 100 mini-batches
                print(f'Training: Epoch [{epoch + 1}, {i + 1}], Loss: {running_loss / 10:.3f}')
                running_loss = 0.0
        
        # Validation phase
        val_loss, val_accuracy = evaluate_model(model, loss_fn, test_loader)
        print(f'End of Epoch {epoch + 1}. Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}')
    
    print('Finished Training')

# Assuming evaluate_model function is defined as per previous discussions
def evaluate_model(model, loss_fn, data_loader):
    model.eval()  # Set the model to evaluation mode
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0

    with torch.no_grad():  # No need to track gradients during evaluation
        for data in data_loader:
            inputs, labels = data
            outputs = model(inputs)
            loss = loss_fn(outputs, labels)
            running_loss += loss.item()

            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total_predictions += labels.size(0)
            correct_predictions += (predicted == labels).sum().item()

    average_loss = running_loss / len(data_loader)
    accuracy = correct_predictions / total_predictions
    return average_loss, accuracy

# %%
train_model(model, optimizer, loss_fn, train_loader, val_loader, epochs=10)
# Out:
# Training: Epoch [1, 10], Loss: 2.223
# Training: Epoch [1, 20], Loss: 2.199
# Training: Epoch [1, 30], Loss: 2.199
# Training: Epoch [1, 40], Loss: 2.187
# Training: Epoch [1, 50], Loss: 2.188
# Training: Epoch [1, 60], Loss: 2.201
# Training: Epoch [1, 70], Loss: 2.166
# Training: Epoch [1, 80], Loss: 2.154
# Training: Epoch [1, 90], Loss: 2.194
# Training: Epoch [1, 100], Loss: 2.187
# Training: Epoch [1, 110], Loss: 2.191
# Training: Epoch [1, 120], Loss: 2.200
# Training: Epoch [1, 130], Loss: 2.205
# Training: Epoch [1, 140], Loss: 2.187
# Training: Epoch [1, 150], Loss: 2.162
# Training: Epoch [1, 160], Loss: 2.184
# Training: Epoch [1, 170], Loss: 2.201
# Training: Epoch [1, 180], Loss: 2.219
# Training: Epoch [1, 190], Loss: 2.183
# Training: Epoch [1, 200], Loss: 2.156
# Training: Epoch [1, 210], Loss: 2.146
# Training: Epoch [1, 220], Loss: 2.174
# Training: Epoch [1, 230], Loss: 2.171
# Training: Epoch [1, 240], Loss: 2.188
# Training: Epoch [1, 250], Loss: 2.154
# Training: Epoch [1, 260], Loss: 2.172
# Training: Epoch [1, 270], Loss: 2.186
# Training: Epoch [1, 280], Loss: 2.172
# Training: Epoch [1, 290], Loss: 2.179
# Training: Epoch [1, 300], Loss: 2.126
# Training: Epoch [1, 310], Loss: 2.168
# Training: Epoch [1, 320], Loss: 2.163
# Training: Epoch [1, 330], Loss: 2.228
# Training: Epoch [1, 340], Loss: 2.180
# Training: Epoch [1, 350], Loss: 2.185
# Training: Epoch [1, 360], Loss: 2.168
# Training: Epoch [1, 370], Loss: 2.161
# Training: Epoch [1, 380], Loss: 2.171
# Training: Epoch [1, 390], Loss: 2.126
# Training: Epoch [1, 400], Loss: 2.143
# End of Epoch 1. Validation Loss: 2.1771, Validation Accuracy: 0.1715
# Training: Epoch [2, 10], Loss: 2.168
# Training: Epoch [2, 20], Loss: 2.156
# Training: Epoch [2, 30], Loss: 2.139
# Training: Epoch [2, 40], Loss: 2.164
# Training: Epoch [2, 50], Loss: 2.148
# Training: Epoch [2, 60], Loss: 2.173
# Training: Epoch [2, 70], Loss: 2.133
# Training: Epoch [2, 80], Loss: 2.118
# Training: Epoch [2, 90], Loss: 2.158
# Training: Epoch [2, 100], Loss: 2.130
# Training: Epoch [2, 110], Loss: 2.167
# Training: Epoch [2, 120], Loss: 2.145
# Training: Epoch [2, 130], Loss: 2.173
# Training: Epoch [2, 140], Loss: 2.128
# Training: Epoch [2, 150], Loss: 2.155
# Training: Epoch [2, 160], Loss: 2.137
# Training: Epoch [2, 170], Loss: 2.149
# Training: Epoch [2, 180], Loss: 2.138
# Training: Epoch [2, 190], Loss: 2.161
# Training: Epoch [2, 200], Loss: 2.123
# Training: Epoch [2, 210], Loss: 2.126
# Training: Epoch [2, 220], Loss: 2.169
# Training: Epoch [2, 230], Loss: 2.135
# Training: Epoch [2, 240], Loss: 2.099
# Training: Epoch [2, 250], Loss: 2.107
# Training: Epoch [2, 260], Loss: 2.152
# Training: Epoch [2, 270], Loss: 2.144
# Training: Epoch [2, 280], Loss: 2.140
# Training: Epoch [7, 310], Loss: 1.956
# Training: Epoch [7, 320], Loss: 1.902
# Training: Epoch [7, 330], Loss: 1.889
# Training: Epoch [7, 340], Loss: 1.891
# Training: Epoch [7, 350], Loss: 1.892
# Training: Epoch [7, 360], Loss: 1.909
# Training: Epoch [7, 370], Loss: 1.992
# Training: Epoch [7, 380], Loss: 1.926
# Training: Epoch [7, 390], Loss: 1.985
# Training: Epoch [7, 400], Loss: 1.879
# End of Epoch 7. Validation Loss: 1.9730, Validation Accuracy: 0.3090
# Training: Epoch [8, 10], Loss: 1.891
# Training: Epoch [8, 20], Loss: 1.872
# Training: Epoch [8, 30], Loss: 1.898
# Training: Epoch [8, 40], Loss: 1.923
# Training: Epoch [8, 50], Loss: 1.953
# Training: Epoch [8, 60], Loss: 1.931
# Training: Epoch [8, 70], Loss: 1.973
# Training: Epoch [8, 80], Loss: 1.886
# Training: Epoch [8, 90], Loss: 1.934
# Training: Epoch [8, 100], Loss: 1.917
# Training: Epoch [8, 110], Loss: 1.920
# Training: Epoch [8, 120], Loss: 1.882
# Training: Epoch [8, 130], Loss: 1.887
# Training: Epoch [8, 140], Loss: 1.903
# Training: Epoch [8, 150], Loss: 1.930
# Training: Epoch [8, 160], Loss: 1.856
# Training: Epoch [8, 170], Loss: 1.897
# Training: Epoch [8, 180], Loss: 1.904
# Training: Epoch [8, 190], Loss: 1.864
# Training: Epoch [8, 200], Loss: 1.893
# Training: Epoch [8, 210], Loss: 1.907
# Training: Epoch [8, 220], Loss: 1.948
# Training: Epoch [8, 230], Loss: 1.850
# Training: Epoch [8, 240], Loss: 1.980
# Training: Epoch [8, 250], Loss: 1.931
# Training: Epoch [8, 260], Loss: 1.887
# Training: Epoch [8, 270], Loss: 1.964
# Training: Epoch [8, 280], Loss: 1.936
# Training: Epoch [8, 290], Loss: 1.940
# Training: Epoch [8, 300], Loss: 1.864
# Training: Epoch [8, 310], Loss: 1.902
# Training: Epoch [8, 320], Loss: 1.907
# Training: Epoch [8, 330], Loss: 1.871
# Training: Epoch [8, 340], Loss: 1.894
# Training: Epoch [8, 350], Loss: 1.891
# Training: Epoch [8, 360], Loss: 1.937
# Training: Epoch [8, 370], Loss: 1.866
# Training: Epoch [8, 380], Loss: 1.906
# Training: Epoch [8, 390], Loss: 1.893
# Training: Epoch [8, 400], Loss: 1.897
# End of Epoch 8. Validation Loss: 1.9479, Validation Accuracy: 0.3129
# Training: Epoch [9, 10], Loss: 1.853
# Training: Epoch [9, 20], Loss: 1.953
# Training: Epoch [9, 30], Loss: 1.870
# Training: Epoch [9, 40], Loss: 1.892
# Training: Epoch [9, 50], Loss: 1.783
# Training: Epoch [9, 60], Loss: 1.892
# Training: Epoch [9, 70], Loss: 1.849
# Training: Epoch [9, 80], Loss: 1.937
# Training: Epoch [9, 90], Loss: 1.895
# Training: Epoch [9, 100], Loss: 1.913
# Training: Epoch [9, 110], Loss: 1.944
# Training: Epoch [9, 120], Loss: 1.899
# Training: Epoch [9, 130], Loss: 1.849
# Training: Epoch [9, 140], Loss: 1.849
# Training: Epoch [9, 150], Loss: 1.928
# Training: Epoch [9, 160], Loss: 1.934
# Training: Epoch [9, 170], Loss: 1.907
# Training: Epoch [9, 180], Loss: 1.911
# Training: Epoch [9, 190], Loss: 1.861
# Training: Epoch [9, 200], Loss: 1.846
# Training: Epoch [9, 210], Loss: 1.930
# Training: Epoch [9, 220], Loss: 1.844
# Training: Epoch [9, 230], Loss: 1.857
# Training: Epoch [9, 240], Loss: 1.904
# Training: Epoch [9, 250], Loss: 1.900
# Training: Epoch [9, 260], Loss: 1.818
# Training: Epoch [9, 270], Loss: 1.848
# Training: Epoch [9, 280], Loss: 1.919
# Training: Epoch [9, 290], Loss: 1.918
# Training: Epoch [9, 300], Loss: 1.878
# Training: Epoch [9, 310], Loss: 1.932
# Training: Epoch [9, 320], Loss: 1.871
# Training: Epoch [9, 330], Loss: 1.879
# Training: Epoch [9, 340], Loss: 1.896
# Training: Epoch [9, 350], Loss: 1.936
# Training: Epoch [9, 360], Loss: 1.891
# Training: Epoch [9, 370], Loss: 1.915
# Training: Epoch [9, 380], Loss: 1.860
# Training: Epoch [9, 390], Loss: 1.875
# Training: Epoch [9, 400], Loss: 1.903
# End of Epoch 9. Validation Loss: 1.9626, Validation Accuracy: 0.3129
# Training: Epoch [10, 10], Loss: 1.877
# Training: Epoch [10, 20], Loss: 1.823
# Training: Epoch [10, 30], Loss: 1.837
# Training: Epoch [10, 40], Loss: 1.841
# Training: Epoch [10, 50], Loss: 1.821
# Training: Epoch [10, 60], Loss: 1.852
# Training: Epoch [10, 70], Loss: 1.870
# Training: Epoch [10, 80], Loss: 1.830
# Training: Epoch [10, 90], Loss: 1.940
# Training: Epoch [10, 100], Loss: 1.845
# Training: Epoch [10, 110], Loss: 1.810
# Training: Epoch [10, 120], Loss: 1.824
# Training: Epoch [10, 130], Loss: 1.867
# Training: Epoch [10, 140], Loss: 1.879
# Training: Epoch [10, 150], Loss: 1.872
# Training: Epoch [10, 160], Loss: 1.809
# Training: Epoch [10, 170], Loss: 1.895
# Training: Epoch [10, 180], Loss: 1.891
# Training: Epoch [10, 190], Loss: 1.924
# Training: Epoch [10, 200], Loss: 1.858
# Training: Epoch [10, 210], Loss: 1.932
# Training: Epoch [10, 220], Loss: 1.921
# Training: Epoch [10, 230], Loss: 1.906
# Training: Epoch [10, 240], Loss: 1.952
# Training: Epoch [10, 250], Loss: 1.905
# Training: Epoch [10, 260], Loss: 1.877
# Training: Epoch [10, 270], Loss: 1.860
# Training: Epoch [10, 280], Loss: 1.844
# Training: Epoch [10, 290], Loss: 1.891
# Training: Epoch [10, 300], Loss: 1.829
# Training: Epoch [10, 310], Loss: 1.799
# Training: Epoch [10, 320], Loss: 1.890
# Training: Epoch [10, 330], Loss: 1.813
# Training: Epoch [10, 340], Loss: 1.861
# Training: Epoch [10, 350], Loss: 1.900
# Training: Epoch [10, 360], Loss: 1.841
# Training: Epoch [10, 370], Loss: 1.897
# Training: Epoch [10, 380], Loss: 1.900
# Training: Epoch [10, 390], Loss: 1.936
# Training: Epoch [10, 400], Loss: 1.849
# End of Epoch 10. Validation Loss: 1.9417, Validation Accuracy: 0.3221
# Finished Training

# %%
# Final evaluation on test set
test_loss, test_accuracy = evaluate_model(model, loss_fn, test_loader)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}')
# Out:
# Test Loss: 1.9454, Test Accuracy: 0.3222
